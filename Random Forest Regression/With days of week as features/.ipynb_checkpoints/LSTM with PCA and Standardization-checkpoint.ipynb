# %%
import pickle
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from scipy.signal import detrend
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# # Data Processing

# %%
sales_data = pd.read_csv('Data/sales dataset.csv')
sales_data['salesDate'] = pd.to_datetime(sales_data['salesDate'], infer_datetime_format=True)
selected_columns1 =['salesAmount', 'salesDate']
sales_data = sales_data[selected_columns1]
##########################################################################

# %%
# The function groups either the expense or sales data into the daily series
# But the first column must be the amount and the second column must be the dates in datetime format
def groupDay(df):
    df['Year'] = df.iloc[:,1].dt.year
    df['Month'] = df.iloc[:,1].dt.month
    df['Day'] = df.iloc[:,1].dt.day
    df['Amount'] = df.iloc[:,0]
    daily = df.groupby(['Year','Month','Day'])['Amount'].sum().reset_index()
    return daily

def dailyToSingleDate(df,Year, Month, Day):
    days = []
    df['date'] = pd.to_datetime(df[['Year','Month','Day']])
    df = df.drop(['Year','Month','Day'], axis=1)
    
    for date in df['date']:
        day_name = date.day_name()
    
        if day_name == 'Sunday':
            days.append('Monday')
        else:
            days.append(day_name)
    df['day_of_week'] = days
#     df = df.set_index('date')   
    return df

# %%
sd = groupDay(sales_data)
daily_sales = dailyToSingleDate(sd, sd['Year'], sd['Month'], sd['Day'])

# %%
dailySales = daily_sales[705:]    #705 for the removal of irrelevant data points
# dailyExpenses = daily_expenses[890:]  #890 for the removal of irrelevant data points
# monthlySales = monthly_sales
# monthlyExpenses = monthly_expenses

# %%
category1 = dailySales
category = category1

# %% [markdown]
# # Remove Outliers

# %%
def remove_outliers_zscore(data, threshold=3):
    z_scores = np.abs((data - np.mean(data)) / np.std(data))
    filtered_data = data[(z_scores < threshold)]
    return filtered_data

filteredCategory = remove_outliers_zscore(category['Amount'])
category['Amount'] = filteredCategory.copy()
category = category.tail(35)
# Out:
# C:\Users\Berlin\AppData\Local\Temp\ipykernel_11156\3845957136.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   category['Amount'] = filteredCategory.copy()

# %% [markdown]
# # One hot encoding

# %%
def onehot(df):
    df['date'] = pd.to_datetime(df['date'])
    df.set_index('date', inplace=True)
    df = pd.get_dummies(df, columns=['day_of_week'], prefix='day')
    return df

# %%
category = onehot(category)
# Out:
# C:\Users\Berlin\AppData\Local\Temp\ipykernel_11156\3065477637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # Adding Lagged Variables

# %%
# lags = [1,2,3,4]
# for lag in lags:
#     category[f'lag{lag}'] = category['Amount'].shift(lag)
# category.dropna(inplace=True)
# selected_columns = ['Amount', 'lag1', 'lag2', 'lag3','lag4','day_Friday','day_Monday','day_Saturday','day_Thursday','day_Tuesday','day_Wednesday']
# category = category[selected_columns]

# %%
category.dropna()
# Out:
#                Amount  day_Friday  day_Monday  day_Saturday  day_Thursday  \
# date
# 2023-10-02  1061494.0           0           1             0             0
# 2023-10-03  1585790.0           0           0             0             0
# 2023-10-04  1784118.0           0           0             0             0
# 2023-10-05  1380207.0           0           0             0             1
# 2023-10-06  1232128.0           1           0             0             0
# 2023-10-07  1224978.0           0           0             1             0
# 2023-10-09  1158278.0           0           1             0             0
# 2023-10-10  1168275.0           0           0             0             0
# 2023-10-11  1802021.0           0           0             0             0
# 2023-10-12  1120984.0           0           0             0             1
# 2023-10-13   961789.0           1           0             0             0
# 2023-10-14  1102110.0           0           0             1             0
# 2023-10-16   734380.0           0           1             0             0
#         -1.17518330e+00, -4.42043322e-01,  1.07059890e-16],
#        [-1.13017350e+00, -5.93305566e-01,  2.56588049e-01,
#          1.98419829e+00, -4.42043322e-01, -4.73157685e-17],
#        [ 1.66295600e-17,  2.37322226e+00,  9.20895139e-17,
#          2.39925901e-16, -4.42043322e-01,  6.10458680e-17],
#        [-5.94511640e-15,  4.72738621e-15,  3.55424091e-14,
#         -1.73774382e-14,  2.65225993e+00, -5.29083507e-17],
#        [-1.81717279e-01, -5.93305566e-01,  1.92625395e+00,
#         -1.23963582e+00, -4.42043322e-01,  1.20095484e-16],
#        [ 2.21629597e+00, -5.93305566e-01, -4.27516423e-01,
#          4.30620826e-01, -4.42043322e-01, -2.55546638e-16],
#        [-9.04405191e-01, -5.93305566e-01, -1.75532558e+00,
#         -1.17518330e+00, -4.42043322e-01,  1.07059890e-16],
#        [-1.13017350e+00, -5.93305566e-01,  2.56588049e-01,
#          1.98419829e+00, -4.42043322e-01, -4.73157685e-17],
#        [ 1.66295600e-17,  2.37322226e+00,  9.20895139e-17,
#          2.39925901e-16, -4.42043322e-01,  6.10458680e-17],
#        [-5.94511640e-15,  4.72738621e-15,  3.55424091e-14,
#         -1.73774382e-14,  2.65225993e+00, -5.29083507e-17],
#        [-1.81717279e-01, -5.93305566e-01,  1.92625395e+00,
#         -1.23963582e+00, -4.42043322e-01,  1.20095484e-16],
#        [ 2.21629597e+00, -5.93305566e-01, -4.27516423e-01,
#          4.30620826e-01, -4.42043322e-01, -2.55546638e-16],
#        [-9.04405191e-01, -5.93305566e-01, -1.75532558e+00,
#         -1.17518330e+00, -4.42043322e-01,  1.07059890e-16],
#        [-1.13017350e+00, -5.93305566e-01,  2.56588049e-01,
#          1.98419829e+00, -4.42043322e-01, -4.73157685e-17],
#        [ 1.66295600e-17,  2.37322226e+00,  9.20895139e-17,
#          2.39925901e-16, -4.42043322e-01,  6.10458680e-17],
#        [-5.94511640e-15,  4.72738621e-15,  3.55424091e-14,
#         -1.73774382e-14,  2.65225993e+00, -5.29083507e-17],
#        [-1.81717279e-01, -5.93305566e-01,  1.92625395e+00,
#         -1.23963582e+00, -4.42043322e-01,  1.20095484e-16],
#        [ 2.21629597e+00, -5.93305566e-01, -4.27516423e-01,
#          4.30620826e-01, -4.42043322e-01, -2.55546638e-16],
#        [-9.04405191e-01, -5.93305566e-01, -1.75532558e+00,
#         -1.17518330e+00, -4.42043322e-01,  1.07059890e-16],
#        [-1.13017350e+00, -5.93305566e-01,  2.56588049e-01,
#          1.98419829e+00, -4.42043322e-01, -4.73157685e-17]])

# %%
# len(X_train)
# # len(X_test)
# len(X_val)

# %% [markdown]
# # Reshape for LSTM input

# %%
X_train_scaled_reshaped = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_scaled_reshaped = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
# X_val_scaled_reshaped = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))

# %% [markdown]
# # Fit the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L2

# %%
model = Sequential()
model.add(LSTM(units=550, return_sequences=True, kernel_regularizer=L2(0.05),activation='tanh', input_shape=(X_train_scaled_reshaped.shape[1], X_train_scaled_reshaped.shape[2])))
model.add(LSTM(units=250, kernel_regularizer=L2(0.07), activation='tanh'))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %%
# cp = ModelCheckpoint('Models Pickled Flies/Sales Day Prediction Model(PCA and Standardization)/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics = [RootMeanSquaredError()])

# %%
model.fit(X_train_scaled_reshaped, y_train, epochs=150)
# Out:
# Epoch 1/150
# 1/1 [==============================] -
150
# 1/1 [==============================] - 0s 114ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 76/150
# 1/1 [==============================] - 0s 123ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 77/150
# 1/1 [==============================] - 0s 110ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 78/150
# 1/1 [==============================] - 0s 115ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 79/150
# 1/1 [==============================] - 0s 111ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 80/150
# 1/1 [==============================] - 0s 111ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 81/150
# 1/1 [==============================] - 0s 110ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 82/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 83/150
# 1/1 [==============================] - 0s 116ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 84/150
# 1/1 [==============================] - 0s 108ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 85/150
# 1/1 [==============================] - 0s 110ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 86/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 87/150
# 1/1 [==============================] - 0s 108ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 88/150
# 1/1 [==============================] - 0s 110ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 89/150
# 1/1 [==============================] - 0s 130ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 90/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 91/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 92/150
# 1/1 [==============================] - 0s 126ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 93/150
# 1/1 [==============================] - 0s 113ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 94/150
# 1/1 [==============================] - 0s 107ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 95/150
# 1/1 [==============================] - 0s 110ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 96/150
# 1/1 [==============================] - 0s 110ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 97/150
# 1/1 [==============================] - 0s 130ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 98/150
# 1/1 [==============================] - 0s 122ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 99/150
# 1/1 [==============================] - 0s 112ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 100/150
# 1/1 [==============================] - 0s 120ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 101/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 102/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 103/150
# 1/1 [==============================] - 0s 119ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 104/150
# 1/1 [==============================] - 0s 115ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 105/150
# 1/1 [==============================] - 0s 114ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 106/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 107/150
# 1/1 [==============================] - 0s 105ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 108/150
# 1/1 [==============================] - 0s 114ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 109/150
# 1/1 [==============================] - 0s 112ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 110/150
# 1/1 [==============================] - 0s 107ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 111/150
# 1/1 [==============================] - 0s 120ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 112/150
# 1/1 [==============================] - 0s 106ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 113/150
# 1/1 [==============================] - 0s 107ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 114/150
# 1/1 [==============================] - 0s 161ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 115/150
# 1/1 [==============================] - 0s 116ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 116/150
# 1/1 [==============================] - 0s 123ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 117/150
# 1/1 [==============================] - 0s 108ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 118/150
# 1/1 [==============================] - 0s 108ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 119/150
# 1/1 [==============================] - 0s 121ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 120/150
# 1/1 [==============================] - 0s 117ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 121/150
# 1/1 [==============================] - 0s 123ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 122/150
# 1/1 [==============================] - 0s 122ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 123/150
# 1/1 [==============================] - 0s 120ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 124/150
# 1/1 [==============================] - 0s 116ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 125/150
# 1/1 [==============================] - 0s 104ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 126/150
# 1/1 [==============================] - 0s 102ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 127/150
# 1/1 [==============================] - 0s 118ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 128/150
# 1/1 [==============================] - 0s 121ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 129/150
# 1/1 [==============================] - 0s 115ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 130/150
# 1/1 [==============================] - 0s 125ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 131/150
# 1/1 [==============================] - 0s 118ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 132/150
# 1/1 [==============================] - 0s 120ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 133/150
# 1/1 [==============================] - 0s 115ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 134/150
# 1/1 [==============================] - 0s 119ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 135/150
# 1/1 [==============================] - 0s 116ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 136/150
# 1/1 [==============================] - 0s 166ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 137/150
# 1/1 [==============================] - 0s 121ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 138/150
# 1/1 [==============================] - 0s 113ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 139/150
# 1/1 [==============================] - 0s 119ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 140/150
# 1/1 [==============================] - 0s 109ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 141/150
# 1/1 [==============================] - 0s 119ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 142/150
# 1/1 [==============================] - 0s 115ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 143/150
# 1/1 [==============================] - 0s 121ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 144/150
# 1/1 [==============================] - 0s 119ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 145/150
# 1/1 [==============================] - 0s 141ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 146/150
# 1/1 [==============================] - 0s 187ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 147/150
# 1/1 [==============================] - 0s 137ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 148/150
# 1/1 [==============================] - 0s 133ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 149/150
# 1/1 [==============================] - 0s 131ms/step - loss: nan - root_mean_squared_error: nan
# Epoch 150/150
# 1/1 [==============================] - 0s 128ms/step - loss: nan - root_mean_squared_error: nan

# %% [markdown]
# # Evaluate Model

# %%
# from tensorflow.keras.models import load_model
# pickledModel = load_model('Models Pickled Flies/Expenses Day Prediction Model(PCA and Standardization)/')

# %%
mse = model.evaluate(X_train_scaled_reshaped, y_train, verbose=0)
print(f'Mean Squared Error is {mse}')
# Out:
# Mean Squared Error is [0.47981712222099304, 0.6244032979011536]

# %%
mse = model.evaluate(X_test_scaled_reshaped, y_test, verbose=0)
print(f'Mean Squared Error is {mse}')
# Out:
# Mean Squared Error is [1.9229886531829834, 1.3539021015167236]
