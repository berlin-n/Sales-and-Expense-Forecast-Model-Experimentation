# %%
import pickle
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from scipy.signal import detrend
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# # Data Processing

# %%
sales_data = pd.read_csv('Data/sales dataset.csv')
sales_data['salesDate'] = pd.to_datetime(sales_data['salesDate'], infer_datetime_format=True)
selected_columns1 =['salesAmount', 'salesDate']
sales_data = sales_data[selected_columns1]
##########################################################################
expenses_data = pd.read_csv('Data/expenses dataset.csv')
expenses_data['expenseDate'] = pd.to_datetime(expenses_data['expenseDate'], infer_datetime_format=True)
selected_columns =['expenseAmount', 'expenseDate']
expenses_data = expenses_data[selected_columns]
##########################################################################
# print('Shape of expenses data', expenses_data.shape)
# print('Shape of sales data', sales_data.shape)
# sales_data

# %%
# The function groups either the expense or sales data into the monthly series
# But the first column must be the amount and the second column must be the dates in datetime format
def groupMonth(df):
    df['Year'] = df.iloc[:,1].dt.year
    df['Month'] = df.iloc[:,1].dt.month
    df['Amount'] = df.iloc[:,0]
    monthly = df.groupby(['Year','Month'])['Amount'].sum().reset_index()
    return monthly

# The function groups either the expense or sales data into the daily series
# But the first column must be the amount and the second column must be the dates in datetime format
def groupDay(df):
    df['Year'] = df.iloc[:,1].dt.year
    df['Month'] = df.iloc[:,1].dt.month
    df['Day'] = df.iloc[:,1].dt.day
    df['Amount'] = df.iloc[:,0]
    daily = df.groupby(['Year','Month','Day'])['Amount'].sum().reset_index()
    return daily

def monthlyToSingleDate(df, Year, Month):
    df['date'] = pd.to_datetime(df['Year'].astype(str) + '-' + df['Month'].astype(str))
    df = df.drop(['Year','Month',], axis=1)
    df = df.set_index('date')
    return df

def dailyToSingleDate(df,Year, Month, Day):
        df['date'] = pd.to_datetime(df[['Year','Month','Day']])
        df = df.drop(['Year','Month','Day'], axis=1)
        df = df.set_index('date')
        return df

# %%
sd = groupDay(sales_data)
ed = groupDay(expenses_data)
em = groupMonth(expenses_data)
sm = groupMonth(sales_data)

daily_sales = dailyToSingleDate(sd, sd['Year'], sd['Month'], sd['Day'])
daily_expenses = dailyToSingleDate(ed, ed['Year'], ed['Month'], ed['Day'])
monthly_expenses = monthlyToSingleDate(em, em['Year'], em['Month'])
monthly_sales = monthlyToSingleDate(sm, sm['Year'], sm['Month'])

# %%
dailySales = daily_sales[705:]    #705 for the removal of irrelevant data points
dailyExpenses = daily_expenses[890:]  #890 for the removal of irrelevant data points
monthlySales = monthly_sales
monthlyExpenses = monthly_expenses

# %%
print(len(monthlyExpenses), len(monthlySales))
print(len(dailyExpenses), len(dailySales))
# Out:
# 43 38
# 182 236

# %%
category1 = dailySales
category2 = dailyExpenses
category3 = monthlySales
category4 = monthlyExpenses
category = category4

# %% [markdown]
# # Remove Outliers

# %%
def remove_outliers_zscore(data, threshold=3):
    z_scores = np.abs((data - np.mean(data)) / np.std(data))
    filtered_data = data[(z_scores < threshold)]
    return filtered_data

filteredCategory = remove_outliers_zscore(category)
category = filteredCategory
category = category.tail(75)
# Out:
# C:\Users\Berlin\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
category.reset_index(inplace=True)
category = pd.DataFrame(category['Amount'])
Category = category

# %% [markdown]
# # Adding Lagged Variables

# %%
lags = [1,2,3]
for lag in lags:
    category[f'lag{lag}'] = category['Amount'].shift(lag)
category.dropna(inplace=True)
selected_columns = ['Amount', 'lag1', 'lag2', 'lag3']
category = category[selected_columns]

# %% [markdown]
# # Standardization

# %%
scaler = StandardScaler()
X = scaler.fit_transform(category.drop(category.columns[0], axis=1))
y = scaler.fit_transform(np.array(category.iloc[:,0]).reshape(-1, 1))

# %% [markdown]
# # PCA

# %%
n_components = len(lags)
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# %% [markdown]
# # Train - Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
len(X_train)
# len(X_test)
# len(X_val)
# Out:
# 28

# %% [markdown]
# # Reshape for LSTM input

# %%
X_train_scaled_reshaped = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_scaled_reshaped = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
# X_val_scaled_reshaped = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))

# %% [markdown]
# # Fit the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L2

# %%
model = Sequential()
model.add(LSTM(units=550, return_sequences=True, kernel_regularizer=L2(0.07),activation='tanh', input_shape=(X_train_scaled_reshaped.shape[1], X_train_scaled_reshaped.shape[2])))
model.add(LSTM(units=250, kernel_regularizer=L2(0.07), activation='tanh'))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %%
cp = ModelCheckpoint('Models Pickled Flies/Sales Day Prediction Model(PCA and Standardization)/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics = [RootMeanSquaredError()])

# %%
model.fit(X_train_scaled_reshaped, y_train, epochs=150, callbacks=[cp])
# Out:
# Epoch 1/150
# 1/1 [==============================] - ETA: 0s - loss: 51.1497 - root_mean_squared_error: 1.0104WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 21s 21s/step - loss: 51.1497 - root_mean_squared_error: 1.0104
# Epoch 2/150
# 1/1 [==============================] - ETA: 0s - loss: 48.7589 - root_mean_squared_error: 1.0045WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 155ms/step - loss: 48.7589 - root_mean_squared_error: 1.0045
# Epoch 3/150
# 1/1 [==============================] - ETA: 0s - loss: 46.4476 - root_mean_squared_error: 0.9992WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 46.4476 - root_mean_squared_error: 0.9992
# Epoch 4/150
# 1/1 [==============================] - ETA: 0s - loss: 44.2163 - root_mean_squared_error: 0.9946WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 151ms/step - loss: 44.2163 - root_mean_squared_error: 0.9946
# Epoch 5/150
# 1/1 [==============================] - ETA: 0s - loss: 42.0639 - root_mean_squared_error: 0.9902WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 152ms/step - loss: 42.0639 - root_mean_squared_error: 0.9902
# Epoch 6/150
# 1/1 [==============================] - ETA: 0s - loss: 39.9893 - root_mean_squared_error: 0.9859WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 139ms/step - loss: 39.9893 - root_mean_squared_error: 0.9859
# Epoch 7/150
# 1/1 [==============================] - ETA: 0s - loss: 37.9917 - root_mean_squared_error: 0.9817WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 135ms/step - loss: 37.9917 - root_mean_squared_error: 0.9817
# Epoch 8/150
# 1/1 [==============================] - ETA: 0s - loss: 36.0703 - root_mean_squared_error: 0.9776WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 177ms/step - loss: 36.0703 - root_mean_squared_error: 0.9776
# Epoch 9/150
# 1/1 [==============================] - ETA: 0s - loss: 34.2238 - root_mean_squared_error: 0.9737WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 130ms/step - loss: 34.2238 - root_mean_squared_error: 0.9737
# Epoch 10/150
# 1/1 [==============================] - ETA: 0s - loss: 32.4512 - root_mean_squared_error: 0.9698WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 131ms/step - loss: 32.4512 - root_mean_squared_error: 0.9698
# Epoch 11/150
# 1/1 [==============================] - ETA: 0s - loss: 30.7509 - root_mean_squared_error: 0.9660WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 136ms/step - loss: 30.7509 - root_mean_squared_error: 0.9660
# Epoch 12/150
# 1/1 [==============================] - ETA: 0s - loss: 29.1214 - root_mean_squared_error: 0.9623WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 135ms/step - loss: 29.1214 - root_mean_squared_error: 0.9623
# Epoch 13/150
# 1/1 [==============================] - ETA: 0s - loss: 27.5612 - root_mean_squared_error: 0.9585WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 131ms/step - loss: 27.5612 - root_mean_squared_error: 0.9585
# Epoch 14/150
# 1/1 [==============================] - ETA: 0s - loss: 26.0686 - root_mean_squared_error: 0.9546WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 133ms/step - loss: 26.0686 - root_mean_squared_error: 0.9546
# Epoch 15/150
# 1/1 [==============================] - ETA: 0s - loss: 24.6418 - root_mean_squared_error: 0.9506WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 140ms/step - loss: 24.6418 - root_mean_squared_error: 0.9506
# Epoch 16/150
# 1/1 [==============================] - ETA: 0s - loss: 23.2788 - root_mean_squared_error: 0.9463WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 130ms/step - loss: 23.2788 - root_mean_squared_error: 0.9463
# Epoch 17/150
# 1/1 [==============================] - ETA: 0s - loss: 21.9779 - root_mean_squared_error: 0.9418WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 122ms/step - loss: 21.9779 - root_mean_squared_error: 0.9418
# Epoch 18/150
# 1/1 [==============================] - ETA: 0s - loss: 20.7375 - root_mean_squared_error: 0.9370WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 172ms/step - loss: 20.7375 - root_mean_squared_error: 0.9370
# Epoch 19/150
# 1/1 [==============================] - ETA: 0s - loss: 19.5553 - root_mean_squared_error: 0.9319WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 132ms/step - loss: 19.5553 - root_mean_squared_error: 0.9319
# Epoch 20/150
# 1/1 [==============================] - ETA: 0s - loss: 18.4300 - root_mean_squared_error: 0.9267WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 132ms/step - loss: 18.4300 - root_mean_squared_error: 0.9267
# Epoch 21/150
# 1/1 [==============================] - ETA: 0s - loss: 17.3596 - root_mean_squared_error: 0.9214WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 150ms/step - loss: 17.3596 - root_mean_squared_error: 0.9214
# Epoch 22/150
# 1/1 [==============================] - ETA: 0s - loss: 16.3423 - root_mean_squared_error: 0.9160WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 163ms/step - loss: 16.3423 - root_mean_squared_error: 0.9160
# Epoch 23/150
# 1/1 [==============================] - ETA: 0s - loss: 15.3761 - root_mean_squared_error: 0.9105WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 136ms/step - loss: 15.3761 - root_mean_squared_error: 0.9105
# Epoch 24/150
# 1/1 [==============================] - ETA: 0s - loss: 14.4594 - root_mean_squared_error: 0.9049WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 196ms/step - loss: 14.4594 - root_mean_squared_error: 0.9049
# Epoch 25/150
# 1/1 [==============================] - ETA: 0s - loss: 13.5903 - root_mean_squared_error: 0.8992WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 165ms/step - loss: 13.5903 - root_mean_squared_error: 0.8992
# Epoch 26/150
# 1/1 [==============================] - ETA: 0s - loss: 12.7672 - root_mean_squared_error: 0.8935WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 136ms/step - loss: 12.7672 - root_mean_squared_error: 0.8935
# Epoch 27/150
# 1/1 [==============================] - ETA: 0s - loss: 11.9884 - root_mean_squared_error: 0.8878WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 166ms/step - loss: 11.9884 - root_mean_squared_error: 0.8878
# Epoch 28/150
# 1/1 [==============================] - ETA: 0s - loss: 11.2523 - root_mean_squared_error: 0.8824WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 134ms/step - loss: 11.2523 - root_mean_squared_error: 0.8824
# Epoch 29/150
# 1/1 [==============================] - ETA: 0s - loss: 10.5572 - root_mean_squared_error: 0.8774WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 160ms/step - loss: 10.5572 - root_mean_squared_error: 0.8774
# Epoch 30/150
# 1/1 [==============================] - ETA: 0s - loss: 9.9016 - root_mean_squared_error: 0.8729WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 141ms/step - loss: 9.9016 - root_mean_squared_error: 0.8729
# Epoch 31/150
# 1/1 [==============================] - ETA: 0s - loss: 9.2837 - root_mean_squared_error: 0.8691WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 9.2837 - root_mean_squared_error: 0.8691
# Epoch 32/150
# 1/1 [==============================] - ETA: 0s - loss: 8.7019 - root_mean_squared_error: 0.8659WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 127ms/step - loss: 8.7019 - root_mean_squared_error: 0.8659
# Epoch 33/150
# 1/1 [==============================] - ETA: 0s - loss: 8.1545 - root_mean_squared_error: 0.8635WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 222ms/step - loss: 8.1545 - root_mean_squared_error: 0.8635
# Epoch 34/150
# 1/1 [==============================] - ETA: 0s - loss: 7.6400 - root_mean_squared_error: 0.8616WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 147ms/step - loss: 7.6400 - root_mean_squared_error: 0.8616
# Epoch 35/150
# 1/1 [==============================] - ETA: 0s - loss: 7.1567 - root_mean_squared_error: 0.8603WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 153ms/step - loss: 7.1567 - root_mean_squared_error: 0.8603
# Epoch 36/150
# 1/1 [==============================] - ETA: 0s - loss: 6.7030 - root_mean_squared_error: 0.8594WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 6.7030 - root_mean_squared_error: 0.8594
# Epoch 37/150
# 1/1 [==============================] - ETA: 0s - loss: 6.2774 - root_mean_squared_error: 0.8587WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 132ms/step - loss: 6.2774 - root_mean_squared_error: 0.8587
# Epoch 38/150
# 1/1 [==============================] - ETA: 0s - loss: 5.8784 - root_mean_squared_error: 0.8583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 166ms/step - loss: 5.8784 - root_mean_squared_error: 0.8583
# Epoch 39/150
# 1/1 [==============================] - ETA: 0s - loss: 5.5044 - root_mean_squared_error: 0.8579WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 221ms/step - loss: 5.5044 - root_mean_squared_error: 0.8579
# Epoch 40/150
# 1/1 [==============================] - ETA: 0s - loss: 5.1543 - root_mean_squared_error: 0.8576WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 183ms/step - loss: 5.1543 - root_mean_squared_error: 0.8576
# Epoch 41/150
# 1/1 [==============================] - ETA: 0s - loss: 4.8267 - root_mean_squared_error: 0.8573WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 224ms/step - loss: 4.8267 - root_mean_squared_error: 0.8573
# Epoch 42/150
# 1/1 [==============================] - ETA: 0s - loss: 4.5203 - root_mean_squared_error: 0.8569WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 142ms/step - loss: 4.5203 - root_mean_squared_error: 0.8569
# Epoch 43/150
# 1/1 [==============================] - ETA: 0s - loss: 4.2341 - root_mean_squared_error: 0.8566WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 157ms/step - loss: 4.2341 - root_mean_squared_error: 0.8566
# Epoch 44/150
# 1/1 [==============================] - ETA: 0s - loss: 3.9670 - root_mean_squared_error: 0.8563WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 162ms/step - loss: 3.9670 - root_mean_squared_error: 0.8563
# Epoch 45/150
# 1/1 [==============================] - ETA: 0s - loss: 3.7180 - root_mean_squared_error: 0.8560WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 175ms/step - loss: 3.7180 - root_mean_squared_error: 0.8560
# Epoch 46/150
# 1/1 [==============================] - ETA: 0s - loss: 3.4859 - root_mean_squared_error: 0.8558WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 138ms/step - loss: 3.4859 - root_mean_squared_error: 0.8558
# Epoch 47/150
# 1/1 [==============================] - ETA: 0s - loss: 3.2700 - root_mean_squared_error: 0.8556WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 199ms/step - loss: 3.2700 - root_mean_squared_error: 0.8556
# Epoch 48/150
# 1/1 [==============================] - ETA: 0s - loss: 3.0693 - root_mean_squared_error: 0.8555WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 166ms/step - loss: 3.0693 - root_mean_squared_error: 0.8555
# Epoch 49/150
# 1/1 [==============================] - ETA: 0s - loss: 2.8828 - root_mean_squared_error: 0.8553WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 162ms/step - loss: 2.8828 - root_mean_squared_error: 0.8553
# Epoch 50/150
# 1/1 [==============================] - ETA: 0s - loss: 2.7097 - root_mean_squared_error: 0.8549WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 162ms/step - loss: 2.7097 - root_mean_squared_error: 0.8549
# Epoch 51/150
# 1/1 [==============================] - ETA: 0s - loss: 2.5491 - root_mean_squared_error: 0.8545WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 147ms/step - loss: 2.5491 - root_mean_squared_error: 0.8545
# Epoch 52/150
# 1/1 [==============================] - ETA: 0s - loss: 2.4002 - root_mean_squared_error: 0.8541WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 146ms/step - loss: 2.4002 - root_mean_squared_error: 0.8541
# Epoch 53/150
# 1/1 [==============================] - ETA: 0s - loss: 2.2624 - root_mean_squared_error: 0.8536WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 158ms/step - loss: 2.2624 - root_mean_squared_error: 0.8536
# Epoch 54/150
# 1/1 [==============================] - ETA: 0s - loss: 2.1349 - root_mean_squared_error: 0.8531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 147ms/step - loss: 2.1349 - root_mean_squared_error: 0.8531
# Epoch 55/150
# 1/1 [==============================] - ETA: 0s - loss: 2.0170 - root_mean_squared_error: 0.8526WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 149ms/step - loss: 2.0170 - root_mean_squared_error: 0.8526
# Epoch 56/150
# 1/1 [==============================] - ETA: 0s - loss: 1.9081 - root_mean_squared_error: 0.8521WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 154ms/step - loss: 1.9081 - root_mean_squared_error: 0.8521
# Epoch 57/150
# 1/1 [==============================] - ETA: 0s - loss: 1.8077 - root_mean_squared_error: 0.8517WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 143ms/step - loss: 1.8077 - root_mean_squared_error: 0.8517
# Epoch 58/150
# 1/1 [==============================] - ETA: 0s - loss: 1.7151 - root_mean_squared_error: 0.8513WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 150ms/step - loss: 1.7151 - root_mean_squared_error: 0.8513
# Epoch 59/150
# 1/1 [==============================] - ETA: 0s - loss: 1.6299 - root_mean_squared_error: 0.8510WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 151ms/step - loss: 1.6299 - root_mean_squared_error: 0.8510
# Epoch 60/150
# 1/1 [==============================] - ETA: 0s - loss: 1.5514 - root_mean_squared_error: 0.8507WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 167ms/step - loss: 1.5514 - root_mean_squared_error: 0.8507
# Epoch 61/150
# 1/1 [==============================] - ETA: 0s - loss: 1.4793 - root_mean_squared_error: 0.8504WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 155ms/step - loss: 1.4793 - root_mean_squared_error: 0.8504
# Epoch 62/150
# 1/1 [==============================] - ETA: 0s - loss: 1.4131 - root_mean_squared_error: 0.8501WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 143ms/step - loss: 1.4131 - root_mean_squared_error: 0.8501
# Epoch 63/150
# 1/1 [==============================] - ETA: 0s - loss: 1.3523 - root_mean_squared_error: 0.8498WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 1.3523 - root_mean_squared_error: 0.8498
# Epoch 64/150
# 1/1 [==============================] - ETA: 0s - loss: 1.2967 - root_mean_squared_error: 0.8496WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 160ms/step - loss: 1.2967 - root_mean_squared_error: 0.8496
# Epoch 65/150
# 1/1 [==============================] - ETA: 0s - loss: 1.2460 - root_mean_squared_error: 0.8498WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 114ms/step - loss: 1.2460 - root_mean_squared_error: 0.8498
# Epoch 66/150
# 1/1 [==============================] - ETA: 0s - loss: 1.1991 - root_mean_squared_error: 0.8494WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 130ms/step - loss: 1.1991 - root_mean_squared_error: 0.8494
# Epoch 67/150
# 1/1 [==============================] - ETA: 0s - loss: 1.1562 - root_mean_squared_error: 0.8493WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 124ms/step - loss: 1.1562 - root_mean_squared_error: 0.8493
# Epoch 68/150
# 1/1 [==============================] - ETA: 0s - loss: 1.1173 - root_mean_squared_error: 0.8493WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 136ms/step - loss: 1.1173 - root_mean_squared_error: 0.8493
# Epoch 69/150
# 1/1 [==============================] - ETA: 0s - loss: 1.0818 - root_mean_squared_error: 0.8492WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 118ms/step - loss: 1.0818 - root_mean_squared_error: 0.8492
# Epoch 70/150
# 1/1 [==============================] - ETA: 0s - loss: 1.0494 - root_mean_squared_error: 0.8490WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 1.0494 - root_mean_squared_error: 0.8490
# Epoch 71/150
# 1/1 [==============================] - ETA: 0s - loss: 1.0198 - root_mean_squared_error: 0.8488WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 1.0198 - root_mean_squared_error: 0.8488
# Epoch 72/150
# 1/1 [==============================] - ETA: 0s - loss: 0.9930 - root_mean_squared_error: 0.8487WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 133ms/step - loss: 0.9930 - root_mean_squared_error: 0.8487
# Epoch 73/150
# 1/1 [==============================] - ETA: 0s - loss: 0.9686 - root_mean_squared_error: 0.8484WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.9686 - root_mean_squared_error: 0.8484
# Epoch 74/150
# 1/1 [==============================] - ETA: 0s - loss: 0.9463 - root_mean_squared_error: 0.8482WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 0.9463 - root_mean_squared_error: 0.8482
# Epoch 75/150
# 1/1 [==============================] - ETA: 0s - loss: 0.9265 - root_mean_squared_error: 0.8483WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 0.9265 - root_mean_squared_error: 0.8483
# Epoch 76/150
# 1/1 [==============================] - ETA: 0s - loss: 0.9090 - root_mean_squared_error: 0.8485WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 118ms/step - loss: 0.9090 - root_mean_squared_error: 0.8485
# Epoch 77/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8917 - root_mean_squared_error: 0.8482WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 0.8917 - root_mean_squared_error: 0.8482
# Epoch 78/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8767 - root_mean_squared_error: 0.8481WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 135ms/step - loss: 0.8767 - root_mean_squared_error: 0.8481
# Epoch 79/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8636 - root_mean_squared_error: 0.8482WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 127ms/step - loss: 0.8636 - root_mean_squared_error: 0.8482
# Epoch 80/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8516 - root_mean_squared_error: 0.8485WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 112ms/step - loss: 0.8516 - root_mean_squared_error: 0.8485
# Epoch 81/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8402 - root_mean_squared_error: 0.8481WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 163ms/step - loss: 0.8402 - root_mean_squared_error: 0.8481
# Epoch 82/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8308 - root_mean_squared_error: 0.8482WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 118ms/step - loss: 0.8308 - root_mean_squared_error: 0.8482
# Epoch 83/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8215 - root_mean_squared_error: 0.8479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 120ms/step - loss: 0.8215 - root_mean_squared_error: 0.8479
# Epoch 84/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8140 - root_mean_squared_error: 0.8482WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 128ms/step - loss: 0.8140 - root_mean_squared_error: 0.8482
# Epoch 85/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8062 - root_mean_squared_error: 0.8476WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 128ms/step - loss: 0.8062 - root_mean_squared_error: 0.8476
# Epoch 86/150
# 1/1 [==============================] - ETA: 0s - loss: 0.8004 - root_mean_squared_error: 0.8478WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 126ms/step - loss: 0.8004 - root_mean_squared_error: 0.8478
# Epoch 87/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7947 - root_mean_squared_error: 0.8481WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.7947 - root_mean_squared_error: 0.8481
# Epoch 88/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7888 - root_mean_squared_error: 0.8476WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.7888 - root_mean_squared_error: 0.8476
# Epoch 89/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7852 - root_mean_squared_error: 0.8480WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 108ms/step - loss: 0.7852 - root_mean_squared_error: 0.8480
# Epoch 90/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7798 - root_mean_squared_error: 0.8474WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 109ms/step - loss: 0.7798 - root_mean_squared_error: 0.8474
# Epoch 91/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7771 - root_mean_squared_error: 0.8480WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 120ms/step - loss: 0.7771 - root_mean_squared_error: 0.8480
# Epoch 92/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7729 - root_mean_squared_error: 0.8471WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 133ms/step - loss: 0.7729 - root_mean_squared_error: 0.8471
# Epoch 93/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7702 - root_mean_squared_error: 0.8472WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 126ms/step - loss: 0.7702 - root_mean_squared_error: 0.8472
# Epoch 94/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7678 - root_mean_squared_error: 0.8475WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 122ms/step - loss: 0.7678 - root_mean_squared_error: 0.8475
# Epoch 95/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7647 - root_mean_squared_error: 0.8470WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.7647 - root_mean_squared_error: 0.8470
# Epoch 96/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7632 - root_mean_squared_error: 0.8472WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 117ms/step - loss: 0.7632 - root_mean_squared_error: 0.8472
# Epoch 97/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7607 - root_mean_squared_error: 0.8470WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.7607 - root_mean_squared_error: 0.8470
# Epoch 98/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7590 - root_mean_squared_error: 0.8469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.7590 - root_mean_squared_error: 0.8469
# Epoch 99/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7576 - root_mean_squared_error: 0.8467WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 122ms/step - loss: 0.7576 - root_mean_squared_error: 0.8467
# Epoch 100/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7557 - root_mean_squared_error: 0.8465WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 105ms/step - loss: 0.7557 - root_mean_squared_error: 0.8465
# Epoch 101/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7546 - root_mean_squared_error: 0.8465WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.7546 - root_mean_squared_error: 0.8465
# Epoch 102/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7545 - root_mean_squared_error: 0.8469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 0.7545 - root_mean_squared_error: 0.8469
# Epoch 103/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7530 - root_mean_squared_error: 0.8468WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 123ms/step - loss: 0.7530 - root_mean_squared_error: 0.8468
# Epoch 104/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7517 - root_mean_squared_error: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 122ms/step - loss: 0.7517 - root_mean_squared_error: 0.8464
# Epoch 105/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7509 - root_mean_squared_error: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 132ms/step - loss: 0.7509 - root_mean_squared_error: 0.8464
# Epoch 106/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7507 - root_mean_squared_error: 0.8469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 127ms/step - loss: 0.7507 - root_mean_squared_error: 0.8469
# Epoch 107/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7496 - root_mean_squared_error: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 115ms/step - loss: 0.7496 - root_mean_squared_error: 0.8464
# Epoch 108/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7488 - root_mean_squared_error: 0.8463WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 138ms/step - loss: 0.7488 - root_mean_squared_error: 0.8463
# Epoch 109/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7487 - root_mean_squared_error: 0.8467WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 123ms/step - loss: 0.7487 - root_mean_squared_error: 0.8467
# Epoch 110/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7478 - root_mean_squared_error: 0.8463WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 136ms/step - loss: 0.7478 - root_mean_squared_error: 0.8463
# Epoch 111/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7471 - root_mean_squared_error: 0.8462WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 180ms/step - loss: 0.7471 - root_mean_squared_error: 0.8462
# Epoch 112/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7476 - root_mean_squared_error: 0.8469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 123ms/step - loss: 0.7476 - root_mean_squared_error: 0.8469
# Epoch 113/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7462 - root_mean_squared_error: 0.8461WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 0.7462 - root_mean_squared_error: 0.8461
# Epoch 114/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7457 - root_mean_squared_error: 0.8460WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 123ms/step - loss: 0.7457 - root_mean_squared_error: 0.8460
# Epoch 115/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7457 - root_mean_squared_error: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 125ms/step - loss: 0.7457 - root_mean_squared_error: 0.8464
# Epoch 116/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7462 - root_mean_squared_error: 0.8466WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 118ms/step - loss: 0.7462 - root_mean_squared_error: 0.8466
# Epoch 117/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7451 - root_mean_squared_error: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 108ms/step - loss: 0.7451 - root_mean_squared_error: 0.8464
# Epoch 118/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7443 - root_mean_squared_error: 0.8459WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 114ms/step - loss: 0.7443 - root_mean_squared_error: 0.8459
# Epoch 119/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7443 - root_mean_squared_error: 0.8461WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 115ms/step - loss: 0.7443 - root_mean_squared_error: 0.8461
# Epoch 120/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7442 - root_mean_squared_error: 0.8463WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 111ms/step - loss: 0.7442 - root_mean_squared_error: 0.8463
# Epoch 121/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7434 - root_mean_squared_error: 0.8458WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.7434 - root_mean_squared_error: 0.8458
# Epoch 122/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7429 - root_mean_squared_error: 0.8457WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 109ms/step - loss: 0.7429 - root_mean_squared_error: 0.8457
# Epoch 123/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7427 - root_mean_squared_error: 0.8457WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 124ms/step - loss: 0.7427 - root_mean_squared_error: 0.8457
# Epoch 124/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7426 - root_mean_squared_error: 0.8456WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 112ms/step - loss: 0.7426 - root_mean_squared_error: 0.8456
# Epoch 125/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7434 - root_mean_squared_error: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 130ms/step - loss: 0.7434 - root_mean_squared_error: 0.8464
# Epoch 126/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7425 - root_mean_squared_error: 0.8457WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 109ms/step - loss: 0.7425 - root_mean_squared_error: 0.8457
# Epoch 127/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7419 - root_mean_squared_error: 0.8457WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 113ms/step - loss: 0.7419 - root_mean_squared_error: 0.8457
# Epoch 128/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7417 - root_mean_squared_error: 0.8454WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 112ms/step - loss: 0.7417 - root_mean_squared_error: 0.8454
# Epoch 129/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7415 - root_mean_squared_error: 0.8454WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 111ms/step - loss: 0.7415 - root_mean_squared_error: 0.8454
# Epoch 130/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7410 - root_mean_squared_error: 0.8451WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.7410 - root_mean_squared_error: 0.8451
# Epoch 131/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7405 - root_mean_squared_error: 0.8449WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.7405 - root_mean_squared_error: 0.8449
# Epoch 132/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7391 - root_mean_squared_error: 0.8440WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 117ms/step - loss: 0.7391 - root_mean_squared_error: 0.8440
# Epoch 133/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7368 - root_mean_squared_error: 0.8420WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 110ms/step - loss: 0.7368 - root_mean_squared_error: 0.8420
# Epoch 134/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7324 - root_mean_squared_error: 0.8389WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 0.7324 - root_mean_squared_error: 0.8389
# Epoch 135/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7306 - root_mean_squared_error: 0.8375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 120ms/step - loss: 0.7306 - root_mean_squared_error: 0.8375
# Epoch 136/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7256 - root_mean_squared_error: 0.8338WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 118ms/step - loss: 0.7256 - root_mean_squared_error: 0.8338
# Epoch 137/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7235 - root_mean_squared_error: 0.8320WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.7235 - root_mean_squared_error: 0.8320
# Epoch 138/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7211 - root_mean_squared_error: 0.8301WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 0.7211 - root_mean_squared_error: 0.8301
# Epoch 139/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7200 - root_mean_squared_error: 0.8288WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 117ms/step - loss: 0.7200 - root_mean_squared_error: 0.8288
# Epoch 140/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7146 - root_mean_squared_error: 0.8247WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 150ms/step - loss: 0.7146 - root_mean_squared_error: 0.8247
# Epoch 141/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7111 - root_mean_squared_error: 0.8211WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 119ms/step - loss: 0.7111 - root_mean_squared_error: 0.8211
# Epoch 142/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7054 - root_mean_squared_error: 0.8161WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 113ms/step - loss: 0.7054 - root_mean_squared_error: 0.8161
# Epoch 143/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7048 - root_mean_squared_error: 0.8145WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 112ms/step - loss: 0.7048 - root_mean_squared_error: 0.8145
# Epoch 144/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7025 - root_mean_squared_error: 0.8121WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 107ms/step - loss: 0.7025 - root_mean_squared_error: 0.8121
# Epoch 145/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7021 - root_mean_squared_error: 0.8115WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.7021 - root_mean_squared_error: 0.8115
# Epoch 146/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7014 - root_mean_squared_error: 0.8110WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 117ms/step - loss: 0.7014 - root_mean_squared_error: 0.8110
# Epoch 147/150
# 1/1 [==============================] - ETA: 0s - loss: 0.7001 - root_mean_squared_error: 0.8102WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 120ms/step - loss: 0.7001 - root_mean_squared_error: 0.8102
# Epoch 148/150
# 1/1 [==============================] - ETA: 0s - loss: 0.6998 - root_mean_squared_error: 0.8100WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.6998 - root_mean_squared_error: 0.8100
# Epoch 149/150
# 1/1 [==============================] - ETA: 0s - loss: 0.6988 - root_mean_squared_error: 0.8093WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6988 - root_mean_squared_error: 0.8093
# Epoch 150/150
# 1/1 [==============================] - ETA: 0s - loss: 0.6980 - root_mean_squared_error: 0.8088WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6980 - root_mean_squared_error: 0.8088

# %% [markdown]
# # Evaluate Model

# %%
# from tensorflow.keras.models import load_model
# pickledModel = load_model('Models Pickled Flies/Expenses Day Prediction Model(PCA and Standardization)/')

# %%
mse = model.evaluate(X_train_scaled_reshaped, y_train, verbose=0)
print(f'Mean Squared Error is {mse}')
# Out:
# Mean Squared Error is [0.6965941786766052, 0.8080230951309204]

# %%
mse = model.evaluate(X_test_scaled_reshaped, y_test, verbose=0)
print(f'Mean Squared Error is {mse}')
# Out:
# Mean Squared Error is [1.6849792003631592, 1.2912849187850952]

# %%
# mse = model.evaluate(X_val_scaled_reshaped, y_val, verbose=0)
# print(f'Mean Squared Error is {mse}')

# %% [markdown]
# # ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
train_predictions = model.predict(X_train_scaled_reshaped)
predictions = scaler.inverse_transform(train_predictions).flatten()
# Out:
# 1/1 [==============================] - 6s 6s/step

# %%
index_start = 4
index = range(index_start, index_start + len(predictions))
df = pd.DataFrame(predictions, index=index, columns=['Values'])

# %%
plt.plot(Category['Amount'], label='Original Data')
plt.plot(df)
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>

# %% [markdown]
# # Make Time Series Predictions

# %%
predictions = model.predict(X_test_scaled_reshaped)
# Out:
# 1/1 [==============================] - 0s 105ms/step
