# %%
import pickle
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from scipy.signal import detrend
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# # Data Processing

# %%
sales_data = pd.read_csv('Data/sales dataset.csv')
sales_data['salesDate'] = pd.to_datetime(sales_data['salesDate'], infer_datetime_format=True)
selected_columns1 =['salesAmount', 'salesDate']
sales_data = sales_data[selected_columns1]
##########################################################################

# %%
# The function groups either the expense or sales data into the daily series
# But the first column must be the amount and the second column must be the dates in datetime format
def groupDay(df):
    df['Year'] = df.iloc[:,1].dt.year
    df['Month'] = df.iloc[:,1].dt.month
    df['Day'] = df.iloc[:,1].dt.day
    df['Amount'] = df.iloc[:,0]
    daily = df.groupby(['Year','Month','Day'])['Amount'].sum().reset_index()
    return daily

def dailyToSingleDate(df,Year, Month, Day):
    days = []
    df['date'] = pd.to_datetime(df[['Year','Month','Day']])
    df = df.drop(['Year','Month','Day'], axis=1)
    
    for date in df['date']:
        day_name = date.day_name()
    
        if day_name == 'Sunday':
            days.append('Monday')
        else:
            days.append(day_name)
    df['day_of_week'] = days
#     df = df.set_index('date')   
    return df

# %%
sd = groupDay(sales_data)
daily_sales = dailyToSingleDate(sd, sd['Year'], sd['Month'], sd['Day'])

# %%
dailySales = daily_sales    #705 for the removal of irrelevant data points
# dailyExpenses = daily_expenses[890:]  #890 for the removal of irrelevant data points
# monthlySales = monthly_sales
# monthlyExpenses = monthly_expenses

# %%
category1 = dailySales
category = category1
category
# Out:
#       Amount       date day_of_week
# 0     504170 2020-10-27     Tuesday
# 1     439435 2020-10-28   Wednesday
# 2     491330 2020-10-29    Thursday
# 3     560504 2020-10-30      Friday
# 4    1197790 2020-10-31    Saturday
# ..       ...        ...         ...
# 936  1396202 2023-11-06      Monday
# 937  1441488 2023-11-07     Tuesday
# 938  1867192 2023-11-08   Wednesday
# 939  1401098 2023-11-09    Thursday
# 940  1664470 2023-11-10      Friday
#
# [941 rows x 3 columns]

# %% [markdown]
# # Remove Outliers

# %%
def remove_outliers_zscore(data, threshold=3):
    z_scores = np.abs((data - np.mean(data)) / np.std(data))
    filtered_data = data[(z_scores < threshold)]
    return filtered_data

filteredCategory = remove_outliers_zscore(category['Amount'])
category['Amount'] = filteredCategory
# category = category.tail(35)

# %%
# category.reset_index(inplace=True)
# category = pd.DataFrame(category['Amount'])
# Category = category

# %% [markdown]
# # Encoding

# %%
day_mapping = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6
}

def onehot(df):
    df['date'] = pd.to_datetime(df['date'])
    df.set_index('date', inplace=True)
    df = pd.get_dummies(df, columns=['day_of_week'], prefix='day').dropna()
    return df

def ordinal(df):
    df['day_of_the_week_encoded'] = df['day_of_week'].map(day_mapping)
    selected_columns = ['Amount','day_of_the_week_encoded']
    df = df[selected_columns].dropna()
    return df

# %%
category = ordinal(category)

# %%
category
# Out:
#         Amount  day_of_the_week_encoded
# 0     504170.0                        2
# 1     439435.0                        3
# 2     491330.0                        4
# 3     560504.0                        5
# 4    1197790.0                        6
# ..         ...                      ...
# 936  1396202.0                        1
# 937  1441488.0                        2
# 938  1867192.0                        3
# 939  1401098.0                        4
# 940  1664470.0                        5
#
# [929 rows x 2 columns]

# %% [markdown]
# # Adding Lagged Variables

# %%
lags = [1,2,3,4]
for lag in lags:
    category[f'lag{lag}'] = category['Amount'].shift(lag)
category.dropna(inplace=True)
selected_columns = ['Amount', 'lag1', 'lag2', 'lag3','lag4','day_Friday','day_Monday','day_Saturday','day_Thursday','day_Tuesday','day_Wednesday']
# selected_columns = ['Amount', 'lag1', 'lag2', 'lag3','day_of_the_week_encoded']
category = category[selected_columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[394], line 7
#       5 selected_columns = ['Amount', 'lag1', 'lag2', 'lag3','lag4','day_Friday','day_Monday','day_Saturday','day_Thursday','day_Tuesday','day_Wednesday']
#       6 # selected_columns = ['Amount', 'lag1', 'lag2', 'lag3','day_of_the_week_encoded']
# ----> 7 category = category[selected_columns]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['day_Friday', 'day_Monday', 'day_Saturday', 'day_Thursday', 'day_Tuesday', 'day_Wednesday'] not in index"

# %%
category

# %%
scaler = StandardScaler()
X = scaler.fit_transform(category.drop(category.columns[0], axis=1))
y = scaler.fit_transform(np.array(category.iloc[:,0]).reshape(-1, 1))

# %% [markdown]
# # PCA

# %%
# n_components = 1
# pca = PCA(n_components=n_components)
# X = pca.fit_transform(X)

# %% [markdown]
# # Train, Test, Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_test
# Out:
# array([[ 0.49911079,  0.6019603 ,  0.49289685,  0.30066369],
#        [ 3.05541574,  0.50088042,  0.60547274,  0.88679963],
#        [-0.86184194,  3.05448203,  0.50435008,  1.47293557],
#        [ 0.2623599 , -0.85863307,  3.05903239, -1.45774414],
#        [-1.23462409,  0.2643799 , -0.85573876, -0.8716082 ],
#        [-0.21241525, -1.231021  ,  0.26774948, -0.28547226],
#        [ 2.09820294, -0.20989317, -1.22828429,  0.30066369],
#        [ 0.33071548,  2.0982815 , -0.20672431,  0.88679963],
#        [-0.22884309,  0.33266319,  2.10242719,  1.47293557],
#        [-1.13626524, -0.22630364,  0.33606166, -1.45774414],
#        [-0.14779348, -1.13276616, -0.22314172, -0.8716082 ],
#        [ 2.23439588, -0.14533974, -1.12998786, -0.28547226],
#        [ 0.80617716,  2.23433041, -0.14214355,  0.30066369],
#        [ 0.74186543,  0.80762206,  2.23853368,  0.88679963],
#        [-0.5802788 ,  0.74337834,  0.81122154,  1.47293557],
#        [-0.92355153, -0.57736769,  0.74695063, -1.45774414],
#        [ 0.10787887, -0.9202774 , -0.57435435, -0.8716082 ],
#        [-0.74174465,  0.11006224, -0.91740918, -0.28547226],
#        [-0.40948288, -0.73866279,  0.11336651,  0.30066369],
#        [ 0.10243541, -0.40675239, -0.73571771,  0.88679963],
#        [ 1.91989513,  0.10462453, -0.40366684,  1.47293557],
#        [-0.06200686,  1.92016225,  0.1079265 , -1.45774414],
#        [-0.43990472, -0.05964383,  1.92423256, -0.8716082 ],
#        [-0.05898615, -0.36705136, -0.01162094, -1.45774414],
#        [-0.87335781, -0.05662632, -0.36394901, -0.8716082 ],
#        [ 0.76010259, -0.87013677, -0.0533926 , -0.28547226],
#        [-0.23091373,  0.76159621, -0.86724733,  0.30066369],
#        [ 2.12746655, -0.22837209,  0.76517621,  0.88679963],
#        [ 0.47982391,  2.12751417, -0.22521105,  1.47293557],
#        [-1.17882968,  0.48161394,  2.13167223, -1.45774414],
#        [-0.89424141, -1.17528559,  0.48507545, -0.8716082 ],
#        [-0.89715581, -0.89099828, -1.17252529, -0.28547226],
#        [-0.24989057, -0.8939096 , -0.88811767,  0.88679963],
#        [ 2.5586962 , -0.24732885, -0.89103022,  1.47293557],
#        [-0.44977515,  2.55828778, -0.24417583, -1.45774414],
#        [ 3.33572099, -0.44700205,  2.56262815, -0.8716082 ],
#        [ 0.5606122 ,  3.33449085, -0.44393354, -0.28547226],
#        [ 1.02369653,  0.56231679,  3.33915971,  0.30066369],
#        [ 1.77052759,  1.0249114 ,  0.56581246,  0.88679963],
#        [-1.22452999,  1.77095267,  1.02860284,  1.47293557],
#        [-1.42270269, -1.22093757,  1.77495983, -1.45774414],
#        [ 0.59230743, -1.4189007 , -1.21819659, -0.8716082 ],
#        [ 0.69259741,  0.59397851, -1.4162435 , -0.28547226],
#        [ 1.63535779,  0.69416243,  0.59748757,  0.30066369],
#        [ 0.60315007,  1.63592582,  0.69771389,  0.88679963]])

# %%
# len(X_train)
# # len(X_test)
# len(X_val)

# %% [markdown]
# # Reshape for LSTM input

# %%
X_train_scaled_reshaped = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_scaled_reshaped = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
# X_val_scaled_reshaped = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))

# %% [markdown]
# # Fit the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L2

# %%
model = Sequential()
model.add(LSTM(units=550, return_sequences=True, activation='tanh', input_shape=(X_train_scaled_reshaped.shape[1], X_train_scaled_reshaped.shape[2])))
model.add(LSTM(units=250, activation='tanh'))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %%
# cp = ModelCheckpoint('Models Pickled Flies/Sales Day Prediction Model(PCA and Standardization)/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics = [RootMeanSquaredError()])

# %%
model.fit(X_train_scaled_reshaped, y_train, epochs=150)
# Out:
# Epoch 1/150
# 24/24 [==============================] - 12s 115ms/step - loss: 0.8855 - root_mean_squared_error: 0.9410
# Epoch 2/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.8419 - root_mean_squared_error: 0.9176
# Epoch 3/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.8303 - root_mean_squared_error: 0.9112
# Epoch 4/150
# 24/24 [==============================] - 3s 107ms/step - loss: 0.8253 - root_mean_squared_error: 0.9085
# Epoch 5/150
# 24/24 [==============================] - 3s 104ms/step - loss: 0.8241 - root_mean_squared_error: 0.9078
# Epoch 6/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.8235 - root_mean_squared_error: 0.9075
# Epoch 7/150
# 24/24 [==============================] - 3s 106ms/step - loss: 0.8393 - root_mean_squared_error: 0.9161
# Epoch 8/150
# 24/24 [==============================] - 3s 106ms/step - loss: 0.8184 - root_mean_squared_error: 0.9046
# Epoch 9/150
# 24/24 [==============================] - 3s 104ms/step - loss: 0.8216 - root_mean_squared_error: 0.9064
# Epoch 10/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.8313 - root_mean_squared_error: 0.9117
# Epoch 11/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.8085 - root_mean_squared_error: 0.8991
# Epoch 12/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.8002 - root_mean_squared_error: 0.8945
# Epoch 13/150
# 24/24 [==============================] - 3s 123ms/step - loss: 0.8173 - root_mean_squared_error: 0.9040
# Epoch 14/150
# 24/24 [==============================] - 3s 122ms/step - loss: 0.8066 - root_mean_squared_error: 0.8981
# Epoch 15/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.7946 - root_mean_squared_error: 0.8914
# Epoch 16/150
# 24/24 [==============================] - 3s 106ms/step - loss: 0.8019 - root_mean_squared_error: 0.8955
# Epoch 17/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.8039 - root_mean_squared_error: 0.8966
# Epoch 18/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.8030 - root_mean_squared_error: 0.8961
# Epoch 19/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7927 - root_mean_squared_error: 0.8903
# Epoch 20/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7947 - root_mean_squared_error: 0.8915
# Epoch 21/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7876 - root_mean_squared_error: 0.8875
# Epoch 22/150
# 24/24 [==============================] - 3s 107ms/step - loss: 0.8054 - root_mean_squared_error: 0.8974
# Epoch 23/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7964 - root_mean_squared_error: 0.8924
# Epoch 24/150
# 24/24 [==============================] - 3s 118ms/step - loss: 0.7892 - root_mean_squared_error: 0.8884
# Epoch 25/150
# 24/24 [==============================] - 3s 129ms/step - loss: 0.7880 - root_mean_squared_error: 0.8877
# Epoch 26/150
# 24/24 [==============================] - 3s 132ms/step - loss: 0.8207 - root_mean_squared_error: 0.9059
# Epoch 27/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7949 - root_mean_squared_error: 0.8916
# Epoch 28/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7919 - root_mean_squared_error: 0.8899
# Epoch 29/150
# 24/24 [==============================] - 3s 114ms/step - loss: 0.7933 - root_mean_squared_error: 0.8907
# Epoch 30/150
# 24/24 [==============================] - 3s 123ms/step - loss: 0.7839 - root_mean_squared_error: 0.8854
# Epoch 31/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7789 - root_mean_squared_error: 0.8826
# Epoch 32/150
# 24/24 [==============================] - 3s 120ms/step - loss: 0.7913 - root_mean_squared_error: 0.8895
# Epoch 33/150
# 24/24 [==============================] - 3s 119ms/step - loss: 0.7824 - root_mean_squared_error: 0.8845
# Epoch 34/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7865 - root_mean_squared_error: 0.8868
# Epoch 35/150
# 24/24 [==============================] - 3s 115ms/step - loss: 0.7822 - root_mean_squared_error: 0.8844
# Epoch 36/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7805 - root_mean_squared_error: 0.8835
# Epoch 37/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7926 - root_mean_squared_error: 0.8903
# Epoch 38/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7813 - root_mean_squared_error: 0.8839
# Epoch 39/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.7791 - root_mean_squared_error: 0.8826
# Epoch 40/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.7885 - root_mean_squared_error: 0.8880
# Epoch 41/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7718 - root_mean_squared_error: 0.8785
# Epoch 42/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7742 - root_mean_squared_error: 0.8799
# Epoch 43/150
# 24/24 [==============================] - 3s 117ms/step - loss: 0.7857 - root_mean_squared_error: 0.8864
# Epoch 44/150
# 24/24 [==============================] - 3s 114ms/step - loss: 0.7623 - root_mean_squared_error: 0.8731
# Epoch 45/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7668 - root_mean_squared_error: 0.8757
# Epoch 46/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7631 - root_mean_squared_error: 0.8736
# Epoch 47/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7536 - root_mean_squared_error: 0.8681
# Epoch 48/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.7709 - root_mean_squared_error: 0.8780
# Epoch 49/150
# 24/24 [==============================] - 3s 104ms/step - loss: 0.7665 - root_mean_squared_error: 0.8755
# Epoch 50/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7650 - root_mean_squared_error: 0.8746
# Epoch 51/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7719 - root_mean_squared_error: 0.8786
# Epoch 52/150
# 24/24 [==============================] - 3s 117ms/step - loss: 0.7677 - root_mean_squared_error: 0.8762
# Epoch 53/150
# 24/24 [==============================] - 3s 114ms/step - loss: 0.7568 - root_mean_squared_error: 0.8699
# Epoch 54/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7458 - root_mean_squared_error: 0.8636
# Epoch 55/150
# 24/24 [==============================] - 3s 120ms/step - loss: 0.7543 - root_mean_squared_error: 0.8685
# Epoch 56/150
# 24/24 [==============================] - 3s 124ms/step - loss: 0.7433 - root_mean_squared_error: 0.8622
# Epoch 57/150
# 24/24 [==============================] - 3s 113ms/step - loss: 0.7466 - root_mean_squared_error: 0.8641
# Epoch 58/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7425 - root_mean_squared_error: 0.8617
# Epoch 59/150
# 24/24 [==============================] - 3s 114ms/step - loss: 0.7504 - root_mean_squared_error: 0.8662
# Epoch 60/150
# 24/24 [==============================] - 3s 114ms/step - loss: 0.7630 - root_mean_squared_error: 0.8735
# Epoch 61/150
# 24/24 [==============================] - 3s 116ms/step - loss: 0.7456 - root_mean_squared_error: 0.8635
# Epoch 62/150
# 24/24 [==============================] - 3s 115ms/step - loss: 0.7468 - root_mean_squared_error: 0.8642
# Epoch 63/150
# 24/24 [==============================] - 3s 115ms/step - loss: 0.7584 - root_mean_squared_error: 0.8709
# Epoch 64/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.7594 - root_mean_squared_error: 0.8715
# Epoch 65/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.7519 - root_mean_squared_error: 0.8671
# Epoch 66/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.7467 - root_mean_squared_error: 0.8641
# Epoch 67/150
# 24/24 [==============================] - 3s 113ms/step - loss: 0.7696 - root_mean_squared_error: 0.8772
# Epoch 68/150
# 24/24 [==============================] - 3s 144ms/step - loss: 0.7616 - root_mean_squared_error: 0.8727
# Epoch 69/150
# 24/24 [==============================] - 4s 164ms/step - loss: 0.7439 - root_mean_squared_error: 0.8625
# Epoch 70/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.7454 - root_mean_squared_error: 0.8634
# Epoch 71/150
# 24/24 [==============================] - 3s 113ms/step - loss: 0.7401 - root_mean_squared_error: 0.8603
# Epoch 72/150
# 24/24 [==============================] - 3s 106ms/step - loss: 0.7343 - root_mean_squared_error: 0.8569
# Epoch 73/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.7348 - root_mean_squared_error: 0.8572
# Epoch 74/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.7285 - root_mean_squared_error: 0.8535
# Epoch 75/150
# 24/24 [==============================] - 3s 107ms/step - loss: 0.7330 - root_mean_squared_error: 0.8562
# Epoch 76/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7304 - root_mean_squared_error: 0.8546
# Epoch 77/150
# 24/24 [==============================] - 3s 106ms/step - loss: 0.7217 - root_mean_squared_error: 0.8496
# Epoch 78/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7212 - root_mean_squared_error: 0.8492
# Epoch 79/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.7568 - root_mean_squared_error: 0.8699
# Epoch 80/150
# 24/24 [==============================] - 3s 113ms/step - loss: 0.7354 - root_mean_squared_error: 0.8576
# Epoch 81/150
# 24/24 [==============================] - 3s 123ms/step - loss: 0.7336 - root_mean_squared_error: 0.8565
# Epoch 82/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.7263 - root_mean_squared_error: 0.8522
# Epoch 83/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7283 - root_mean_squared_error: 0.8534
# Epoch 84/150
# 24/24 [==============================] - 3s 115ms/step - loss: 0.7220 - root_mean_squared_error: 0.8497
# Epoch 85/150
# 24/24 [==============================] - 3s 132ms/step - loss: 0.7251 - root_mean_squared_error: 0.8516
# Epoch 86/150
# 24/24 [==============================] - 3s 116ms/step - loss: 0.7044 - root_mean_squared_error: 0.8393
# Epoch 87/150
# 24/24 [==============================] - 3s 120ms/step - loss: 0.7163 - root_mean_squared_error: 0.8463
# Epoch 88/150
# 24/24 [==============================] - 3s 114ms/step - loss: 0.7077 - root_mean_squared_error: 0.8412
# Epoch 89/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.7201 - root_mean_squared_error: 0.8486
# Epoch 90/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.6982 - root_mean_squared_error: 0.8356
# Epoch 91/150
# 24/24 [==============================] - 3s 113ms/step - loss: 0.7167 - root_mean_squared_error: 0.8466
# Epoch 92/150
# 24/24 [==============================] - 3s 116ms/step - loss: 0.7066 - root_mean_squared_error: 0.8406
# Epoch 93/150
# 24/24 [==============================] - 3s 115ms/step - loss: 0.7043 - root_mean_squared_error: 0.8392
# Epoch 94/150
# 24/24 [==============================] - 3s 120ms/step - loss: 0.7055 - root_mean_squared_error: 0.8399
# Epoch 95/150
# 24/24 [==============================] - 3s 123ms/step - loss: 0.6986 - root_mean_squared_error: 0.8358
# Epoch 96/150
# 24/24 [==============================] - 3s 119ms/step - loss: 0.7010 - root_mean_squared_error: 0.8373
# Epoch 97/150
# 24/24 [==============================] - 3s 122ms/step - loss: 0.7030 - root_mean_squared_error: 0.8384
# Epoch 98/150
# 24/24 [==============================] - 3s 110ms/step - loss: 0.6896 - root_mean_squared_error: 0.8304
# Epoch 99/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.6969 - root_mean_squared_error: 0.8348
# Epoch 100/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.6973 - root_mean_squared_error: 0.8350
# Epoch 101/150
# 24/24 [==============================] - 3s 112ms/step - loss: 0.6813 - root_mean_squared_error: 0.8254
# Epoch 102/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.6859 - root_mean_squared_error: 0.8282
# Epoch 103/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6851 - root_mean_squared_error: 0.8277
# Epoch 104/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6793 - root_mean_squared_error: 0.8242
# Epoch 105/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6840 - root_mean_squared_error: 0.8271
# Epoch 106/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6933 - root_mean_squared_error: 0.8327
# Epoch 107/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6748 - root_mean_squared_error: 0.8215
# Epoch 108/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6729 - root_mean_squared_error: 0.8203
# Epoch 109/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6696 - root_mean_squared_error: 0.8183
# Epoch 110/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6712 - root_mean_squared_error: 0.8193
# Epoch 111/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.7053 - root_mean_squared_error: 0.8398
# Epoch 112/150
# 24/24 [==============================] - 3s 107ms/step - loss: 0.7190 - root_mean_squared_error: 0.8479
# Epoch 113/150
# 24/24 [==============================] - 2s 104ms/step - loss: 0.6685 - root_mean_squared_error: 0.8176
# Epoch 114/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6772 - root_mean_squared_error: 0.8229
# Epoch 115/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6605 - root_mean_squared_error: 0.8127
# Epoch 116/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6654 - root_mean_squared_error: 0.8157
# Epoch 117/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6547 - root_mean_squared_error: 0.8091
# Epoch 118/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6459 - root_mean_squared_error: 0.8037
# Epoch 119/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6602 - root_mean_squared_error: 0.8125
# Epoch 120/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.6509 - root_mean_squared_error: 0.8068
# Epoch 121/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6533 - root_mean_squared_error: 0.8083
# Epoch 122/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6473 - root_mean_squared_error: 0.8046
# Epoch 123/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6340 - root_mean_squared_error: 0.7962
# Epoch 124/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6435 - root_mean_squared_error: 0.8022
# Epoch 125/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.6439 - root_mean_squared_error: 0.8024
# Epoch 126/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6200 - root_mean_squared_error: 0.7874
# Epoch 127/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6392 - root_mean_squared_error: 0.7995
# Epoch 128/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6296 - root_mean_squared_error: 0.7935
# Epoch 129/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6224 - root_mean_squared_error: 0.7889
# Epoch 130/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6998 - root_mean_squared_error: 0.8366
# Epoch 131/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6589 - root_mean_squared_error: 0.8117
# Epoch 132/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6647 - root_mean_squared_error: 0.8153
# Epoch 133/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6204 - root_mean_squared_error: 0.7876
# Epoch 134/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6239 - root_mean_squared_error: 0.7899
# Epoch 135/150
# 24/24 [==============================] - 3s 104ms/step - loss: 0.6204 - root_mean_squared_error: 0.7876
# Epoch 136/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6213 - root_mean_squared_error: 0.7883
# Epoch 137/150
# 24/24 [==============================] - 2s 104ms/step - loss: 0.5994 - root_mean_squared_error: 0.7742
# Epoch 138/150
# 24/24 [==============================] - 3s 113ms/step - loss: 0.5992 - root_mean_squared_error: 0.7741
# Epoch 139/150
# 24/24 [==============================] - 2s 104ms/step - loss: 0.5939 - root_mean_squared_error: 0.7707
# Epoch 140/150
# 24/24 [==============================] - 2s 98ms/step - loss: 0.6241 - root_mean_squared_error: 0.7900
# Epoch 141/150
# 24/24 [==============================] - 2s 96ms/step - loss: 0.5837 - root_mean_squared_error: 0.7640
# Epoch 142/150
# 24/24 [==============================] - 2s 96ms/step - loss: 0.5926 - root_mean_squared_error: 0.7698
# Epoch 143/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.5679 - root_mean_squared_error: 0.7536
# Epoch 144/150
# 24/24 [==============================] - 2s 98ms/step - loss: 0.5602 - root_mean_squared_error: 0.7484
# Epoch 145/150
# 24/24 [==============================] - 2s 96ms/step - loss: 0.5721 - root_mean_squared_error: 0.7564
# Epoch 146/150
# 24/24 [==============================] - 2s 97ms/step - loss: 0.5736 - root_mean_squared_error: 0.7574
# Epoch 147/150
# 24/24 [==============================] - 2s 96ms/step - loss: 0.5755 - root_mean_squared_error: 0.7586
# Epoch 148/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.5923 - root_mean_squared_error: 0.7696
# Epoch 149/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.5598 - root_mean_squared_error: 0.7482
# Epoch 150/150
# 24/24 [==============================] - 2s 96ms/step - loss: 0.5581 - root_mean_squared_error: 0.7471

# %% [markdown]
# # Evaluate Model

# %%
# from tensorflow.keras.models import load_model
# pickledModel = load_model('Models Pickled Flies/Expenses Day Prediction Model(PCA and Standardization)/')

# %%
mse = model.evaluate(X_train_scaled_reshaped, y_train, verbose=0)
print(f'Mean Squared Error is {mse}')
# Out:
# Mean Squared Error is [0.5149543285369873, 0.7176032066345215]

# %%
mse = model.evaluate(X_test_scaled_reshaped, y_test, verbose=0)
print(f'Mean Squared Error is {mse}')
# Out:
# Mean Squared Error is [1.1378986835479736, 1.066723346710205]

# %%
# mse = model.evaluate(X_val_scaled_reshaped, y_val, verbose=0)
# print(f'Mean Squared Error is {mse}')

# %% [markdown]
# # ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
train_predictions = model.predict(X_train_scaled_reshaped)
predictions = scaler.inverse_transform(train_predictions).flatten()
# Out:
# 24/24 [==============================] - 2s 19ms/step

# %%
index_start = 0
index = range(index_start, index_start + len(predictions))
df = pd.DataFrame(predictions, index=index, columns=['Values'])

# %%
plt.plot(Category['Amount'], label='Original Data')
plt.plot(df)
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>
