# %% [markdown]
# Lab 4 Solution

# %%
import numpy as np
import os

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

X = [3, 4, 3, 8]

y = ['Red', 'Black', 'Blue', 'White']

# %%
plt.scatter(X, y)

# %%
#add ones to the left using np.c_[np.ones((row,column)),X]
X_1
# Out:
# [[1. 1.]
#  [1. 2.]
#  [1. 3.]]

# %%
#np.linalg.inv()
#T for transpose
#. when adding T or dot
#dot() or np.dot(,) for the dot product 
theta_value =
# Out:
# [[1.5]
#  [0.5]]

# %%
#choose two values as a new point for X
Xnew = 

#add ones using  np.C_
X_new_1 = 

#get y_predict by getting the dot product of new X and theta
y_predict = 
y_predict
# Out:
# array([[1.5],
#        [4. ]])

# %%
plt.plot(Xnew, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0,2,0,10])
plt.show()

# %%
import numpy as np
#lets use random dataset
#using np.random.rand(100,1)
X = 

#add p.random.rand(100,1) to y to get a random spread
y = 3 * X 
#np.power(X,3)

# %%
plt.plot(X, y, "b.")
plt.axis([0,2,0,15])
plt.show()

# %%
#add ones using np.c_
X_1 = 
theta =
print(theta)
# Out:
# [[0.51359766]
#  [2.98323418]]

# %%
#check new value
Xnew = 
X_new_1 =
y_predict =
# Out:
# array([[ 0.51359766],
#        [15.42976855]])

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.plot(Xnew, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0,2,0,15])
plt.show()

# %%
#Using scikit learn
from sklearn.linear_model import LinearRegression

X = 2 * np.random.rand(100, 1)
y = 3 * X + np.random.rand(100,1)

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_

X_new = np.array([[0], [2]])
y_predict = lin_reg.predict(X_new)

plt.plot(X_new, y_predict, "g--")
plt.plot(X, y, "r.")
plt.axis([0,2,0,15])
plt.show()

# %%
#using scikit lean on a real dataset
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# Load the diabetes dataset
diabetes = datasets.load_diabetes()

# Use only one feature
print(diabetes.data[np.newaxis])
diabetes_X = diabetes.data[:, np.newaxis, 2]

### start code ###


### END code ###

# Create linear regression object

# Train the model using the training sets

# Make predictions using the testing set
diabetes_y_pred = 
print(diabetes_X_test[1])
print(diabetes_y_pred[1])

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='r')
plt.plot(diabetes_X_test, diabetes_y_pred, color='g', linewidth=1)


plt.show()
# Out:
# [[[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990842
#    -0.01764613]
#   [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06832974
#    -0.09220405]
#   [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286377
#    -0.02593034]
#   ...
#   [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04687948
#     0.01549073]
#   [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452837
#    -0.02593034]
#   [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00421986
#     0.00306441]]]
# [-0.046085]
# 108.72003665734088
